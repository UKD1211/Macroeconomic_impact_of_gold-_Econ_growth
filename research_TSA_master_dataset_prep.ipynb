# %% [markdown]
# <a href="https://colab.research.google.com/github/UKD1211/Macroeconomic_impact_of_gold-_Econ_growth/blob/main/research_TSA_master_dataset_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_gold_master = pd.read_excel("/content/clean_gold_master.xlsx")

# %%
df_gold_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
# [315 rows x 4 columns]

# %%
df_cpi_11_14_gold = pd.read_excel("/content/CPIndex_Jan11-To-Dec14_gold.xlsx")

# %%
df_cpi_11_14_gold
# Out:
#     Year      Month  Item-Code Description  Combined Index
# 0   2011    January     506181        gold           111.7
# 1   2011   February     506181        gold           111.7
# 2   2011      March     506181        gold           114.3
# 3   2011      April     506181        gold           117.3
# 4   2011        May     506181        gold           120.3
# 5   2011       June     506181        gold           122.0
# 6   2011       July     506181        gold           123.8
# 7   2011     August     506181        gold           141.2
# 8   2011  September     506181        gold           147.4
# 9   2011    October     506181        gold           146.3
# 10  2011   November     506181        gold           154.3
# 11  2011   December     506181        gold           153.7
# 12  2012    January     506181        gold           151.0
# 13  2012   February     506181        gold           152.5
# 14  2012      March     506181        gold           152.3
# ...

# %%
df_cpi_15_25_gold = pd.read_excel("/content/CPIndex_Jan15-To-Dec25_gold.xlsx")

# %%
df_cpi_15_25_gold
# Out:
#     All India Item Combined Index (Base 2012=100) Unnamed: 1       Unnamed: 2  \
# 0                                            Year      Month        Item-Code
# 1                                            2015    January  6.1.06.2.1.01.0
# 2                                            2015   February  6.1.06.2.1.01.0
# 3                                            2015      March  6.1.06.2.1.01.0
# 4                                            2015      April  6.1.06.2.1.01.0
# ..                                            ...        ...              ...
# 125                                          2025     August  6.1.06.2.1.01.0
# 126                                          2025  September  6.1.06.2.1.01.0
# 127                                          2025    October  6.1.06.2.1.01.0
# 128                                          2025   November  6.1.06.2.1.01.0
# 129                                          2025   December  6.1.06.2.1.01.0
#
#       Unnamed: 3      Unnamed: 4
# ...

# %%
df_inr_usd = pd.read_csv("/content/INR_USD_conversion_rates.csv")

# %%
df_inr_usd
# Out:
#      observation_date  DEXINUS
# 0          2000-01-03    43.55
# 1          2000-01-04    43.55
# 2          2000-01-05    43.55
# 3          2000-01-06    43.55
# 4          2000-01-07    43.55
# ...               ...      ...
# 6880       2026-05-18    96.35
# 6881       2026-05-19    96.53
# 6882       2026-05-20    96.82
# 6883       2026-05-21    96.20
# 6884       2026-05-22    95.69
#
# [6885 rows x 2 columns]

# %%
df_repo_rate = pd.read_excel("/content/Policy Rate Month End India Repo Rate(2).xlsx")

# %%
df_repo_rate
# Out:
#               Unnamed: 0 Policy Rate: Month End: India: Repo Rate
# 0                 Region                                    India
# 1            Subnational                                      NaN
# 2              Frequency                                  Monthly
# 3                   Unit                                     % pa
# 4                 Source                                CEIC Data
# ..                   ...                                      ...
# 324  2025-12-01 00:00:00                                     5.25
# 325  2026-01-01 00:00:00                                     5.25
# 326  2026-02-01 00:00:00                                     5.25
# 327  2026-03-01 00:00:00                                     5.25
# 328  2026-04-01 00:00:00                                     5.25
#
# [329 rows x 2 columns]

# %%
month_map = {
    'January':'01',
    'February':'02',
    'March':'03',
    'April':'04',
    'May':'05',
    'June':'06',
    'July':'07',
    'August':'08',
    'September':'09',
    'October':'10',
    'November':'11',
    'December':'12'
}

df_cpi_11_14_gold['Date'] = (
    df_cpi_11_14_gold['Year'].astype(str)
    + '-'
    + df_cpi_11_14_gold['Month'].map(month_map)
)

df_cpi_11_14_gold = df_cpi_11_14_gold[
    ['Date','Combined Index']
]

df_cpi_11_14_gold.columns = [
    'Date',
    'Gold_CPI'
]

# %%
df_cpi_15_25_gold.columns = [
    'Year',
    'Month',
    'Item_Code',
    'Description',
    'Gold_CPI'
]

df_cpi_15_25_gold['Date'] = (
    df_cpi_15_25_gold['Year'].astype(str)
    + '-'
    + df_cpi_15_25_gold['Month'].map(month_map)
)

df_cpi_15_25_gold = df_cpi_15_25_gold[
    ['Date','Gold_CPI']
]

# %%
df_gold_cpi = pd.concat(
    [
        df_cpi_11_14_gold,
        df_cpi_15_25_gold
    ],
    ignore_index=True
)

df_gold_cpi = (
    df_gold_cpi
    .sort_values('Date')
    .reset_index(drop=True)
)

# %%
df_gold_cpi
# Out:
#         Date        Gold_CPI
# 0    2011-01           111.7
# 1    2011-02           111.7
# 2    2011-03           114.3
# 3    2011-04           117.3
# 4    2011-05           120.3
# ..       ...             ...
# 173  2025-09           359.4
# 174  2025-10           404.2
# 175  2025-11           408.4
# 176  2025-12           433.9
# 177      NaN  Combined Index
#
# [178 rows x 2 columns]

# %%
df_gold_master = pd.merge(
    df_gold_master,
    df_gold_cpi,
    on='Date',
    how='left'
)

# %%
df_gold_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
#     Gold_CPI
# 0        NaN
# 1        NaN
# ...

# %%
df_gold_master['Gold_CPI'] = (
    df_gold_master['Gold_CPI']
    .fillna('---')
)

# %%
df_gold_master_with_cpi = df_gold_master.copy()

# %%
df_gold_master_with_cpi.to_excel(
    "gold_master_dataset_with_cpi.xlsx",
    index=False
)

# %%
# Rename columns
df_inr_usd.columns = ['Date', 'USDINR']

# Convert Date column
df_inr_usd['Date'] = pd.to_datetime(
    df_inr_usd['Date'],
    errors='coerce'
)

# Convert exchange rate to numeric
df_inr_usd['USDINR'] = pd.to_numeric(
    df_inr_usd['USDINR'],
    errors='coerce'
)

# Remove invalid rows
df_inr_usd = df_inr_usd.dropna()

# Convert date to Year-Month
df_inr_usd['Date'] = (
    df_inr_usd['Date']
    .dt.strftime('%Y-%m')
)

# Monthly average
df_inr_usd = (
    df_inr_usd
    .groupby('Date', as_index=False)
    ['USDINR']
    .mean()
)

# Round values
df_inr_usd['USDINR'] = (
    df_inr_usd['USDINR']
    .round(2)
)

# Sort
df_inr_usd = (
    df_inr_usd
    .sort_values('Date')
    .reset_index(drop=True)
)

df_inr_usd.head()
# Out:
# /tmp/ipykernel_1043/3790533072.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inr_usd['Date'] = (
#       Date  USDINR
# 0  2000-01   43.59
# 1  2000-02   43.65
# 2  2000-03   43.64
# 3  2000-04   43.68
# 4  2000-05   44.08

# %%
df_inr_usd
# Out:
#         Date  USDINR
# 0    2000-01   43.59
# 1    2000-02   43.65
# 2    2000-03   43.64
# 3    2000-04   43.68
# 4    2000-05   44.08
# ..       ...     ...
# 312  2026-01   90.90
# 313  2026-02   90.75
# 314  2026-03   92.82
# 315  2026-04   93.48
# 316  2026-05   95.54
#
# [317 rows x 2 columns]

# %%
df_master = pd.merge(
    df_gold_master,
    df_inr_usd,
    on='Date',
    how='left'
)

# %%
df_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
#     Gold_CPI  USDINR
# 0        ---   43.59
# ...

# %%
# Rename columns
df_repo_rate.columns = ['Date', 'Repo_Rate']

# Convert Date
df_repo_rate['Date'] = pd.to_datetime(
    df_repo_rate['Date'],
    errors='coerce'
)

# Keep only valid date rows
df_repo_rate = df_repo_rate[
    df_repo_rate['Date'].notna()
]

# Convert repo rate to numeric
df_repo_rate['Repo_Rate'] = pd.to_numeric(
    df_repo_rate['Repo_Rate'],
    errors='coerce'
)

# Keep from 2000 onward
df_repo_rate = df_repo_rate[
    df_repo_rate['Date'] >= '2000-01-01'
]

# Convert to YYYY-MM
df_repo_rate['Date'] = (
    df_repo_rate['Date']
    .dt.strftime('%Y-%m')
)

# Sort
df_repo_rate = (
    df_repo_rate
    .sort_values('Date')
    .reset_index(drop=True)
)

df_repo_rate.head()
# Out:
# /tmp/ipykernel_1043/756264131.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_repo_rate['Date'] = pd.to_datetime(
# /tmp/ipykernel_1043/756264131.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_repo_rate['Repo_Rate'] = pd.to_numeric(
#       Date  Repo_Rate
# 0  2001-04       8.75
# 1  2001-05       8.75
# 2  2001-06       8.50
# 3  2001-07       8.50
# 4  2001-08       8.50

# %%
df_repo_rate
# Out:
#         Date  Repo_Rate
# 0    2001-04       8.75
# 1    2001-05       8.75
# 2    2001-06       8.50
# 3    2001-07       8.50
# 4    2001-08       8.50
# ..       ...        ...
# 296  2025-12       5.25
# 297  2026-01       5.25
# 298  2026-02       5.25
# 299  2026-03       5.25
# 300  2026-04       5.25
#
# [301 rows x 2 columns]

# %%
df_master = pd.merge(
    df_master,
    df_repo_rate,
    on='Date',
    how='left'
)

# %%
df_master['Repo_Rate'] = (
    df_master['Repo_Rate']
    .fillna('---')
)

# %%
df_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
#     Gold_CPI  USDINR Repo_Rate
# ...

# %%
df_cpi_overall_13_25 = pd.read_csv("/content/CPIndex_overall_2013-To-2025.csv")

# %%
df_cpi_overall_13_25
# Out:
#                                                                                                                    Combined CPI (Base 2012=100)
# Year State     Description                Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec                             NaN
# 2013 ALL India General Index (All Groups) 104.6 105.3 105.5 106.1 106.9 109.3 111.0 112.4 113.7 114.8 116.3 114.5                           NaN
# 2014 ALL India General Index (All Groups) 113.6 113.6 114.2 115.1 115.8 116.7 119.2 120.3 120.1 120.1 120.1 119.4                           NaN
# 2015 ALL India General Index (All Groups) 119.5 119.7 120.2 120.7 121.6 123.0 123.6 124.8 125.4 126.1 126.6 126.1                           NaN
# 2016 ALL India General Index (All Groups) 126.3 126.0 126.0 127.3 128.6 130.1 131.1 131.1 130.9 131.4 131.2 130.4                           NaN
# ...

# %%
df_cpi_overall_13_25.columns
# Out:
# Index(['Combined CPI (Base 2012=100)'], dtype='object')

# %%
print(df_cpi_overall_13_25.columns.tolist())
# Out:
# ['Combined CPI (Base 2012=100)']

# %%
df_cpi_overall_13_25.head()
# Out:
#                                                                                                                    Combined CPI (Base 2012=100)
# Year State     Description                Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec                             NaN
# 2013 ALL India General Index (All Groups) 104.6 105.3 105.5 106.1 106.9 109.3 111.0 112.4 113.7 114.8 116.3 114.5                           NaN
# 2014 ALL India General Index (All Groups) 113.6 113.6 114.2 115.1 115.8 116.7 119.2 120.3 120.1 120.1 120.1 119.4                           NaN
# 2015 ALL India General Index (All Groups) 119.5 119.7 120.2 120.7 121.6 123.0 123.6 124.8 125.4 126.1 126.6 126.1                           NaN
# 2016 ALL India General Index (All Groups) 126.3 126.0 126.0 127.3 128.6 130.1 131.1 131.1 130.9 131.4 131.2 130.4                           NaN

# %%
print(df_cpi_overall_13_25.shape)

df_cpi_overall_13_25.head(5)
# Out:
# (14, 1)
#                                                                                                                    Combined CPI (Base 2012=100)
# Year State     Description                Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec                             NaN
# 2013 ALL India General Index (All Groups) 104.6 105.3 105.5 106.1 106.9 109.3 111.0 112.4 113.7 114.8 116.3 114.5                           NaN
# 2014 ALL India General Index (All Groups) 113.6 113.6 114.2 115.1 115.8 116.7 119.2 120.3 120.1 120.1 120.1 119.4                           NaN
# 2015 ALL India General Index (All Groups) 119.5 119.7 120.2 120.7 121.6 123.0 123.6 124.8 125.4 126.1 126.6 126.1                           NaN
# 2016 ALL India General Index (All Groups) 126.3 126.0 126.0 127.3 128.6 130.1 131.1 131.1 130.9 131.4 131.2 130.4                           NaN

# %%
df_cpi_overall_13_25.columns = [
    col[1] if isinstance(col, tuple) else col
    for col in df_cpi_overall_13_25.columns
]

# %%
print(df_cpi_overall_13_25.columns.tolist())
# Out:
# ['Combined CPI (Base 2012=100)']

# %%
type(df_cpi_overall_13_25.iloc[0,0])
# Out:
# numpy.float64

# %%
df_cpi_overall_13_25.iloc[0,0]
# Out:
# np.float64(nan)

# %%
df_cpi_overall_13_25.head(3).to_dict()
# Out:
# {'Combined CPI (Base 2012=100)': {('Year',
#    'State',
#    'Description',
#    'Jan',
#    'Feb',
#    'Mar',
#    'Apr',
#    'May',
#    'Jun',
#    'Jul',
#    'Aug',
#    'Sep',
#    'Oct',
#    'Nov',
#    'Dec'): nan,
#   ('2013',
#    'ALL India',
#    'General Index (All Groups)',
#    '104.6',
#    '105.3',
#    '105.5',
#    '106.1',
#    '106.9',
#    '109.3',
#    '111.0',
#    '112.4',
#    '113.7',
#    '114.8',
#    '116.3',
#    '114.5'): nan,
#   ('2014',
#    'ALL India',
#    'General Index (All Groups)',
#    '113.6',
#    '113.6',
#    '114.2',
#    '115.1',
#    '115.8',
#    '116.7',
#    '119.2',
#    '120.3',
#    '120.1',
#    '120.1',
#    '120.1',
#    '119.4'): nan}}

# %%
print(df_cpi_overall_13_25.index)
# Out:
# MultiIndex([('Year',     'State',                'Description',   'Jan', ...),
#             ('2013', 'ALL India', 'General Index (All Groups)', '104.6', ...),
#             ('2014', 'ALL India', 'General Index (All Groups)', '113.6', ...),
#             ('2015', 'ALL India', 'General Index (All Groups)', '119.5', ...),
#             ('2016', 'ALL India', 'General Index (All Groups)', '126.3', ...),
#             ('2017', 'ALL India', 'General Index (All Groups)', '130.3', ...),
#             ('2018', 'ALL India', 'General Index (All Groups)', '136.9', ...),
#             ('2019', 'ALL India', 'General Index (All Groups)', '139.6', ...),
#             ('2020', 'ALL India', 'General Index (All Groups)', '150.2', ...),
#             ('2021', 'ALL India', 'General Index (All Groups)', '156.3', ...),
#             ('2022', 'ALL India', 'General Index (All Groups)', '165.7', ...),
#             ('2023', 'ALL India', 'General Index (All Groups)', '176.5', ...),
# ...

# %%
# Convert MultiIndex to dataframe
df_cpi_overall_master = pd.DataFrame(
    df_cpi_overall_13_25.index.tolist()
)

# Use first row as column names
df_cpi_overall_master.columns = df_cpi_overall_master.iloc[0]

# Remove header row
df_cpi_overall_master = df_cpi_overall_master.iloc[1:]

# Reset index
df_cpi_overall_master = df_cpi_overall_master.reset_index(drop=True)

df_cpi_overall_master.head()
# Out:
# 0  Year      State                 Description    Jan    Feb    Mar    Apr  \
# 0  2013  ALL India  General Index (All Groups)  104.6  105.3  105.5  106.1
# 1  2014  ALL India  General Index (All Groups)  113.6  113.6  114.2  115.1
# 2  2015  ALL India  General Index (All Groups)  119.5  119.7  120.2  120.7
# 3  2016  ALL India  General Index (All Groups)  126.3  126.0  126.0  127.3
# 4  2017  ALL India  General Index (All Groups)  130.3  130.6  130.9  131.1
#
# 0    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec
# 0  106.9  109.3  111.0  112.4  113.7  114.8  116.3  114.5
# 1  115.8  116.7  119.2  120.3  120.1  120.1  120.1  119.4
# 2  121.6  123.0  123.6  124.8  125.4  126.1  126.6  126.1
# 3  128.6  130.1  131.1  131.1  130.9  131.4  131.2  130.4
# 4  131.4  132.0  134.2  135.4  135.2  136.1  137.6  137.2

# %%
month_cols = [
    'Jan','Feb','Mar','Apr','May','Jun',
    'Jul','Aug','Sep','Oct','Nov','Dec'
]

df_cpi_overall_master = df_cpi_overall_master.melt(
    id_vars='Year',
    value_vars=month_cols,
    var_name='Month',
    value_name='Overall_CPI'
)

# %%
month_map = {
    'Jan':'01',
    'Feb':'02',
    'Mar':'03',
    'Apr':'04',
    'May':'05',
    'Jun':'06',
    'Jul':'07',
    'Aug':'08',
    'Sep':'09',
    'Oct':'10',
    'Nov':'11',
    'Dec':'12'
}

df_cpi_overall_master['Date'] = (
    df_cpi_overall_master['Year'].astype(str)
    + '-'
    + df_cpi_overall_master['Month'].map(month_map)
)

df_cpi_overall_master = (
    df_cpi_overall_master[['Date','Overall_CPI']]
    .sort_values('Date')
    .reset_index(drop=True)
)

# %%
df_cpi_overall_master
# Out:
#         Date Overall_CPI
# 0    2013-01       104.6
# 1    2013-02       105.3
# 2    2013-03       105.5
# 3    2013-04       106.1
# 4    2013-05       106.9
# ..       ...         ...
# 151  2025-08       197.0
# 152  2025-09       197.0
# 153  2025-10       197.3
# 154  2025-11       197.9
# 155  2025-12       198.0
#
# [156 rows x 2 columns]

# %%
df_cpi_overall_master.shape
# Out:
# (156, 2)

# %%
df_cpi_overall_master.to_excel(
    "cpi_overall_master.xlsx",
    index=False
)

# %%
df_master = pd.merge(
    df_master,
    df_cpi_overall_master,
    on='Date',
    how='left'
)

# %%
df_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
#     Gold_CPI  USDINR Repo_Rate Overall_CPI
# ...

# %%
df_master['Overall_CPI'] = df_master['Overall_CPI'].fillna("---")

# %%
df_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
#     Gold_CPI  USDINR Repo_Rate Overall_CPI
# ...

# %%
import numpy as np
import pandas as pd

# Convert Overall_CPI to numeric just in case
df_master['Overall_CPI'] = pd.to_numeric(
    df_master['Overall_CPI'],
    errors='coerce'
)

# Year-on-Year Inflation (%)
df_master['Inflation_YoY'] = (
    df_master['Overall_CPI']
    .pct_change(periods=12)
    * 100
)

# Month-on-Month Inflation (%)
df_master['Inflation_MoM'] = (
    df_master['Overall_CPI']
    .pct_change(periods=1)
    * 100
)

# Round values
df_master['Inflation_YoY'] = (
    df_master['Inflation_YoY']
    .round(2)
)

df_master['Inflation_MoM'] = (
    df_master['Inflation_MoM']
    .round(2)
)

# Optional: replace NaN with '---' for display/reporting
df_master['Inflation_YoY'] = (
    df_master['Inflation_YoY']
    .fillna('---')
)

df_master['Inflation_MoM'] = (
    df_master['Inflation_MoM']
    .fillna('---')
)

df_master.head()
# Out:
# /tmp/ipykernel_1043/1521117497.py:13: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   .pct_change(periods=12)
# /tmp/ipykernel_1043/1521117497.py:20: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   .pct_change(periods=1)
#       Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0  2000-01               2945.0               11.502339            4510.75
# 1  2000-02               3104.0               11.502339            4712.25
# 2  2000-03               2974.0               11.502339            4541.90
# ...

# %%
df_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
# ...

# %%
df_master['Overall_CPI'] = df_master['Overall_CPI'].fillna("---")

# %%
df_master
# Out:
#         Date  Gold_Reservs_USD_mn  Gold_Volume_mn_troy_oz  Gold_Price[/10gm]  \
# 0    2000-01               2945.0               11.502339            4510.75
# 1    2000-02               3104.0               11.502339            4712.25
# 2    2000-03               2974.0               11.502339            4541.90
# 3    2000-04               2895.0               11.502339            4462.06
# 4    2000-05               2851.0               11.502339            4371.14
# ..       ...                  ...                     ...                ...
# 310  2025-11             106740.0               28.298487          122834.00
# 311  2025-12             111262.0               28.303688          131322.55
# 312  2026-01             126904.0               28.303707          146169.80
# 313  2026-02             131630.0               28.303709          154370.40
# 314  2026-03             115395.0               28.309308          147395.00
#
# ...

# %%
df_master.to_excel(
    "gold_master_dataset_with_cpi_and_inflation.xlsx",
    index=False
)
